# %%
import pandas as pd
import numpy as np
url = 'https://raw.githubusercontent.com/rashakil-ds/Public-Datasets/main/automobile.csv'
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0        111
# 1          130         mpfi  3.47    2.68               9.0        111
# 2          152         mpfi  2.68    3.47               9.0        154
# 3          109         mpfi  3.19     3.4              10.0        102
# 4          136         mpfi  3.19     3.4               8.0        115
#
#    peak-rpm city-mpg highway-mpg  price
# 0      5000       21          27  13495
# 1      5000       21          27  16500
# 2      5000       19          26  16500
# 3      5500       24          30  13950
# 4      5500       18          22  17450
#
# [5 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %% [markdown]
# # Goal & Steps:

# %% [markdown]
# 1. Predicting Car Prices:
#    - Task: Build a regression model to predict the price (y=price) of cars based on other features in the dataset. This could involve preprocessing the data, selecting relevant features, and implementing `linear regression` and `KNN` algorithm.
#
# 2. Feature Engineering:
#    - Task: Challenge students to come up with creative ways to engineer new features from the existing ones. For example, they could create a new feature representing the ratio of horsepower to curb weight.
#
# 3. Exploratory Data Analysis (EDA):
#    - Task: Have students perform in-depth exploratory data analysis to understand the relationships between different features. Visualization tools can be used to communicate their findings effectively.
#
# 4. Handling Missing Data:
#    - Task: Teach students how to handle missing data in a dataset. They can explore different strategies such as imputation or removal of missing values.
#
# 5. Training:
#    - Task: Use relavant ML Models
#
# 6. Model evaluation:
# - Evaluate models and Summarizing their findings. This should include a clear explanation of the model's performance and any insights gained from the analysis.

# %%
df.to_csv("Assignment_2.csv")

# %%
df1 =df.copy()
df2 =df.copy()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202 entries, 0 to 201
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          202 non-null    int64
#  1   normalized-losses  165 non-null    float64
#  2   make               202 non-null    object
#  3   fuel-type          202 non-null    object
#  4   aspiration         202 non-null    object
#  5   num-of-doors       200 non-null    object
#  6   body-style         202 non-null    object
#  7   drive-wheels       202 non-null    object
#  8   engine-location    202 non-null    object
#  9   wheel-base         202 non-null    float64
#  10  length             202 non-null    float64
#  11  width              202 non-null    float64
#  12  height             202 non-null    float64
#  13  curb-weight        202 non-null    int64
#  14  engine-type        202 non-null    object
#  15  num-of-cylinders   202 non-null    object
#  16  engine-size        202 non-null    int64
#  17  fuel-system        202 non-null    object
#  18  bore               202 non-null    object
#  19  stroke             202 non-null    object
#  20  compression-ratio  202 non-null    float64
#  21  horsepower         202 non-null    object
#  22  peak-rpm           202 non-null    object
#  23  city-mpg           202 non-null    int64
#  24  highway-mpg        202 non-null    int64
#  25  price              202 non-null    int64
# dtypes: float64(6), int64(6), object(14)
# memory usage: 41.2+ KB

# %%
df1.isnull().sum()
# Out:
# symboling             0
# normalized-losses    37
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  0
# stroke                0
# compression-ratio     0
# horsepower            0
# peak-rpm              0
# city-mpg              0
# highway-mpg           0
# price                 0
# dtype: int64

# %%
df1.replace("?",np.nan,inplace=True)

# %%
df1
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                NaN  alfa-romero       gas        std
# 1            3                NaN  alfa-romero       gas        std
# 2            1                NaN  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 197         -1               95.0        volvo       gas      turbo
# 198         -1               95.0        volvo       gas        std
# 199         -1               95.0        volvo    diesel      turbo
# 200         -1               95.0        volvo       gas      turbo
# 201         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# 1            two  convertible          rwd           front        88.6  ...
# 2            two    hatchback          rwd           front        94.5  ...
# 3           four        sedan          fwd           front        99.8  ...
# 4           four        sedan          4wd           front        99.4  ...
# ..           ...          ...          ...             ...         ...  ...
# 197         four        sedan          rwd           front       109.1  ...
# 198         four        sedan          rwd           front       109.1  ...
# 199         four        sedan          rwd           front       109.1  ...
# 200         four        sedan          rwd           front       109.1  ...
# 201         four        sedan          rwd           front       109.1  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0            130         mpfi  3.47    2.68               9.0        111
# 1            130         mpfi  3.47    2.68               9.0        111
# 2            152         mpfi  2.68    3.47               9.0        154
# 3            109         mpfi  3.19     3.4              10.0        102
# 4            136         mpfi  3.19     3.4               8.0        115
# ..           ...          ...   ...     ...               ...        ...
# 197          141         mpfi  3.78    3.15               8.7        160
# 198          173         mpfi  3.58    2.87               8.8        134
# 199          145          idi  3.01     3.4              23.0        106
# 200          141         mpfi  3.78    3.15               9.5        114
# 201          141         mpfi  3.78    3.15               9.5        114
#
#      peak-rpm city-mpg highway-mpg  price
# 0        5000       21          27  13495
# 1        5000       21          27  16500
# 2        5000       19          26  16500
# 3        5500       24          30  13950
# 4        5500       18          22  17450
# ..        ...      ...         ...    ...
# 197      5300       19          25  19045
# 198      5500       18          23  21485
# 199      4800       26          27  22470
# 200      5400       19          25  22625
# 201      5400       19          25  22625
#
# [202 rows x 26 columns]

# %%
# change column data types
numeric_columns = ['bore', 'stroke', 'horsepower', 'peak-rpm']
for col in numeric_columns:
    df1[col] = pd.to_numeric(df1[col], errors='coerce')

# %%
df1.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
# one hot encoded
categorical_columns = [
    'make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style',
    'drive-wheels', 'engine-location', 'engine-type',
    'num-of-cylinders', 'fuel-system'
]

df1 = pd.get_dummies(df1, columns=categorical_columns, drop_first=True)

# %%
df1.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# wheel-base           float64
# length               float64
# width                float64
#                       ...
# fuel-system_idi         bool
# fuel-system_mfi         bool
# fuel-system_mpfi        bool
# fuel-system_spdi        bool
# fuel-system_spfi        bool
# Length: 65, dtype: object

# %%
df1
# Out:
#      symboling  normalized-losses  wheel-base  length  width  height  \
# 0            3                NaN        88.6   168.8   64.1    48.8
# 1            3                NaN        88.6   168.8   64.1    48.8
# 2            1                NaN        94.5   171.2   65.5    52.4
# 3            2              164.0        99.8   176.6   66.2    54.3
# 4            2              164.0        99.4   176.6   66.4    54.3
# ..         ...                ...         ...     ...    ...     ...
# 197         -1               95.0       109.1   188.8   68.8    55.5
# 198         -1               95.0       109.1   188.8   68.9    55.5
# 199         -1               95.0       109.1   188.8   68.9    55.5
# 200         -1               95.0       109.1   188.8   68.9    55.5
# 201         -1               95.0       109.1   188.8   68.9    55.5
#
#      curb-weight  engine-size  bore  stroke  ...  num-of-cylinders_three  \
# 0           2548          130  3.47    2.68  ...                   False
# 1           2548          130  3.47    2.68  ...                   False
# 2           2823          152  2.68    3.47  ...                   False
# 3           2337          109  3.19    3.40  ...                   False
# 4           2824          136  3.19    3.40  ...                   False
# ..           ...          ...   ...     ...  ...                     ...
# 197         3049          141  3.78    3.15  ...                   False
# 198         3012          173  3.58    2.87  ...                   False
# 199         3217          145  3.01    3.40  ...                   False
# 200         3062          141  3.78    3.15  ...                   False
# 201         3062          141  3.78    3.15  ...                   False
#
#      num-of-cylinders_twelve  num-of-cylinders_two  fuel-system_2bbl  \
# 0                      False                 False             False
# 1                      False                 False             False
# 2                      False                 False             False
# 3                      False                 False             False
# 4                      False                 False             False
# ..                       ...                   ...               ...
# 197                    False                 False             False
# 198                    False                 False             False
# 199                    False                 False             False
# 200                    False                 False             False
# 201                    False                 False             False
#
#      fuel-system_4bbl  fuel-system_idi  fuel-system_mfi  fuel-system_mpfi  \
# 0               False            False            False              True
# 1               False            False            False              True
# 2               False            False            False              True
# 3               False            False            False              True
# 4               False            False            False              True
# ..                ...              ...              ...               ...
# 197             False            False            False              True
# 198             False            False            False              True
# 199             False             True            False             False
# 200             False            False            False              True
# 201             False            False            False              True
#
#      fuel-system_spdi  fuel-system_spfi
# 0               False             False
# 1               False             False
# 2               False             False
# 3               False             False
# 4               False             False
# ..                ...               ...
# 197             False             False
# 198             False             False
# 199             False             False
# 200             False             False
# 201             False             False
#
# [202 rows x 65 columns]

# %%
# fill the missing value
df1 = df1.apply(lambda x: x.fillna(x.mean()) if x.dtype in [np.float64, np.int64] else x)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202 entries, 0 to 201
# Data columns (total 65 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   symboling                202 non-null    int64
#  1   normalized-losses        202 non-null    float64
#  2   wheel-base               202 non-null    float64
#  3   length                   202 non-null    float64
#  4   width                    202 non-null    float64
#  5   height                   202 non-null    float64
#  6   curb-weight              202 non-null    int64
#  7   engine-size              202 non-null    int64
#  8   bore                     202 non-null    float64
#  9   stroke                   202 non-null    float64
#  10  compression-ratio        202 non-null    float64
#  11  horsepower               202 non-null    float64
#  12  peak-rpm                 202 non-null    float64
#  13  city-mpg                 202 non-null    int64
#  14  highway-mpg              202 non-null    int64
#  15  price                    202 non-null    int64
#  16  make_audi                202 non-null    bool
#  17  make_bmw                 202 non-null    bool
#  18  make_chevrolet           202 non-null    bool
#  19  make_dodge               202 non-null    bool
#  20  make_honda               202 non-null    bool
#  21  make_isuzu               202 non-null    bool
#  22  make_jaguar              202 non-null    bool
#  23  make_mazda               202 non-null    bool
#  24  make_mercedes-benz       202 non-null    bool
#  25  make_mercury             202 non-null    bool
#  26  make_mitsubishi          202 non-null    bool
#  27  make_nissan              202 non-null    bool
#  28  make_peugot              202 non-null    bool
#  29  make_plymouth            202 non-null    bool
#  30  make_porsche             202 non-null    bool
#  31  make_renault             202 non-null    bool
#  32  make_saab                202 non-null    bool
#  33  make_subaru              202 non-null    bool
#  34  make_toyota              202 non-null    bool
#  35  make_volkswagen          202 non-null    bool
#  36  make_volvo               202 non-null    bool
#  37  fuel-type_gas            202 non-null    bool
#  38  aspiration_turbo         202 non-null    bool
#  39  num-of-doors_two         202 non-null    bool
#  40  body-style_hardtop       202 non-null    bool
#  41  body-style_hatchback     202 non-null    bool
#  42  body-style_sedan         202 non-null    bool
#  43  body-style_wagon         202 non-null    bool
#  44  drive-wheels_fwd         202 non-null    bool
#  45  drive-wheels_rwd         202 non-null    bool
#  46  engine-location_rear     202 non-null    bool
#  47  engine-type_l            202 non-null    bool
#  48  engine-type_ohc          202 non-null    bool
#  49  engine-type_ohcf         202 non-null    bool
#  50  engine-type_ohcv         202 non-null    bool
#  51  engine-type_rotor        202 non-null    bool
#  52  num-of-cylinders_five    202 non-null    bool
#  53  num-of-cylinders_four    202 non-null    bool
#  54  num-of-cylinders_six     202 non-null    bool
#  55  num-of-cylinders_three   202 non-null    bool
#  56  num-of-cylinders_twelve  202 non-null    bool
#  57  num-of-cylinders_two     202 non-null    bool
#  58  fuel-system_2bbl         202 non-null    bool
#  59  fuel-system_4bbl         202 non-null    bool
#  60  fuel-system_idi          202 non-null    bool
#  61  fuel-system_mfi          202 non-null    bool
#  62  fuel-system_mpfi         202 non-null    bool
#  63  fuel-system_spdi         202 non-null    bool
#  64  fuel-system_spfi         202 non-null    bool
# dtypes: bool(49), float64(10), int64(6)
# memory usage: 35.0 KB

# %%
df1.to_csv("Update_data.csv")

# %%
# Featured Engineering
df1["hp_to_weight"] = df1["horsepower"] / df1["curb-weight"] #his ratio measures how much power the car has relative to its weight
df1["length_to_width"] = df1["length"] / df["width"] # Captures the proportions of the car's shape
df["car_volume"] = df["length"] * df["width"] * df["height"] # Size of the car

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(6, 4))
sns.histplot(df1["hp_to_weight"], kde=True, bins=30, color='skyblue')
plt.title("Distribution of Horsepower-to-Weight Ratio")
plt.xlabel("hp_to_weight")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.scatterplot(x=df1["hp_to_weight"], y=df1["price"])
plt.title("Horsepower-to-Weight vs Price")
plt.xlabel("hp_to_weight")
plt.ylabel("Price")
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.scatterplot(x=df1["length_to_width"], y=df1["price"])
plt.title("Length-to-Width Ratio vs Price")
plt.xlabel("length_to_width")
plt.ylabel("Price")
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
X = df1.drop(columns=['price'])  # features
y = df1['price']                 # target

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
y_pred_lin = lin_reg.predict(X_test)
mse_lin = mean_squared_error(y_test, y_pred_lin)
r2_lin = r2_score(y_test, y_pred_lin)

# %%
print(mse_lin)
print(r2_lin)
# Out:
# 11605972.114937324
# 0.8706041232299598

# %%
knn = KNeighborsRegressor(n_neighbors=5)
knn.fit(X_train_scaled, y_train)
y_pred_knn = knn.predict(X_test_scaled)
mse_knn = mean_squared_error(y_test, y_pred_knn)
r2_knn = r2_score(y_test, y_pred_knn)

# %%
print(mse_knn )
print(r2_knn)
# Out:
# 24926755.236065574
# 0.7220896865113385

# %%
# Relevant ML Model
from xgboost import XGBRegressor

xgb = XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=5, random_state=42)
xgb.fit(X_train_scaled, y_train)
y_pred_xgb = xgb.predict(X_test_scaled)

# %%
mse_xgb = mean_squared_error(y_test, y_pred_xgb)
r2_xgb = r2_score(y_test, y_pred_xgb)

# %%
print(mse_xgb)
print(r2_xgb)
# Out:
# 4900899.5
# 0.945359468460083

# %% [markdown]
# Xgb perform better compare to KNN and Linear Regression
